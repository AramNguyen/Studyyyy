# %% [markdown]
# ## Artificial Intelligence & Machine Learning

# %% [markdown]
# ### What is the difference between AI - ML - DL

# %% [markdown]
# **AI contain Machine Learning containe Deep Learning**
#
# - AI relates to sense, watch, intelligence things
#
# - While, Machine Learning are related more on algorithm, huge dataset
#
# - Finall, Deep Learning is a mase of neutral network, huge dataset,...

# %% [markdown]
# ---

# %% [markdown]
# ### What features are and what an target is

# %% [markdown]
# ##### Features seem like attributes of the data
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Target is a column we wanna predict
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **The idea is to use the four features, sepal lenght, sepal width, petal lenght, petal width in oder to predict the species**

# %% [markdown]
# ### Two types of Machine Learning
#
# #####   + Supervised Learning
#
# #####   + Unsupervised Learning

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For unsupervised learning --> there is no right or wrong answer
#
# The example for unsupervised learning, customer segmentation --> Suppose that you're a customer and the bank have the dataset of 10 thousand customers
#
# - The unsupervised learning is about to learn the type of every customer has the same attribute, then group them into a category

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Don't forget to get target be careful
