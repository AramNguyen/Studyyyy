# %%
import numpy as np #Import the Numpy Library

# %% [markdown]
# Theory
#
# English
#
# A end ndaray is a homogeneous n-dimensional array
# This mean all the elements share the same data type and value
# ![image.png](attachment:image.png)
# axes : trục
# Viet
# Một mảng cuối ndaray là mảng n chiều đồng nhất
